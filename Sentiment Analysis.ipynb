# %% [markdown]
# ### Google Cloud ML

# %%
# Imports the Google Cloud client library
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types
import os
from google.oauth2 import service_account

# %%
credential = service_account.Credentials.from_service_account_file('/Users/panherbert/google-auth/_google-key.json')

# %%
# Instantiates a client
client = language.LanguageServiceClient(credentials=credential)

# The text to analyze
text = u'''
Defective card

After trying and trying repeatedly to use this microcard as a replacement in my Samsung S7 - hours of frustration, seeking guidance from internet, friends, etc. I gave up, thinking it was just my ineptitude. Tried again several times, it would never work.
Finally, decided to try a different/new card. Sure enough...worked right away! So, by now the 128 GB card ordered May 2, is well past its "return by" date, when I determine it is defective. Now what do I do? Searched on Amazon, but found no instructions for this situation.
Giving it 1 star in hopes this can be rectified. I use SanDisk cards all the time and have never had a problem like this before.

Just found out from SanDisk that this card is a fake - not their product. Guess I am screwed unless Amazon steps up and makes it
good. Need to somehow punish this seller "Lecu Computer" for giving Amazon a bad name and customers a bad product!
'''

# %%
document = types.Document(
    content='text',
    type=enums.Document.Type.PLAIN_TEXT)

# Detects the sentiment of the text
sentiment = client.analyze_sentiment(document=document).document_sentiment

print('Text: {}'.format(text))
print('Sentiment: {}, {}'.format(sentiment.score, sentiment.magnitude))

# %% [markdown]
# ### NLTK

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
sid.polarity_scores('heck yes')

# %% [markdown]
# ### Textblob

# %%
from textblob import TextBlob
TextBlob('heck yes').seheckntiment

# %% [markdown]
# ### Flair

# %%
import flair
from flair import data
flair_sentiment = flair.models.TextClassifier.load('en-sentiment')

# %%
data.Sentence(text)

# %%
s = flair.data.Sentence(text)
flair_sentiment.predict(s)
total_sentiment = s.labels
total_sentiment

# %%
def senti(text):
    s = data.Sentence(text)
    flair_sentiment.predict(s)
    return s.labels

# %%
senti('heck yes')

# %% [markdown]
# ### AWS

# %%
import boto3

# %%
client = boto3.client('comprehend')

# %%
response = client.batch_detect_sentiment(
    TextList=[
        'Hello World'
    ],
    LanguageCode='en'
)

# %%
import pprint
p = lambda x: pprint.PrettyPrinter(depth=6).pprint(x)

# %%
p(response)
# Out:
# {'ErrorList': [],
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '205',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Thu, 22 Aug 2019 04:15:18 GMT',
#                                       'x-amzn-requestid': 'd43e3291-56a7-4f6f-b470-bc7e0397adc2'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'd43e3291-56a7-4f6f-b470-bc7e0397adc2',
#                       'RetryAttempts': 0},
#  'ResultList': [{'Index': 0,
#                  'Sentiment': 'NEUTRAL',
#                  'SentimentScore': {'Mixed': 0.0078077297657728195,
#                                     'Negative': 0.02092457003891468,
#                                     'Neutral': 0.8059531450271606,
#                                     'Positive': 0.16531452536582947}}]}

# %%
p(response['ResultList'])
# Out:
# [{'Index': 0,
#   'Sentiment': 'NEUTRAL',
#   'SentimentScore': {'Mixed': 0.0078077297657728195,
#                      'Negative': 0.02092457003891468,
#                      'Neutral': 0.8059531450271606,
#                      'Positive': 0.16531452536582947}}]

# %% [markdown]
# ### Analysing with AWS

# %%
from pymongo import MongoClient
from bson.objectid import ObjectId

# %%
db = MongoClient('mongodb://@54.183.229.143', 27017)

# %%
questions = db.project.questions.find({})

# %%
reviews = db.project.reviews.find({})

# %%
import pandas as pd
import numpy as np
from IPython.display import clear_output

# %%
col = db.project.reviews.find({},{
    '_id':1,
    'review_id':1,
    'title':1,
    'content':1
})

# %%
df = pd.DataFrame(col)

# %%
df = df[['_id', 'review_id', 'title', 'content']]
df['corpus'] = df[['title','content']].apply(lambda x: ' '.join(x), axis=1)
combined_df = df[['_id', 'review_id', 'corpus']]
combined_df
# Out:
#                             _id       review_id  \
# 0      5d53b24de7f56061ea1f9581   RKQOUIP1W33UT
# 1      5d53b24de7f56061ea1f9582  R1358Q1HMSSK1T
# 2      5d53b24de7f56061ea1f9583  R2BU293VXBCL1H
# 3      5d53b24de7f56061ea1f9584  R24XBDBSZ6AKZ3
# 4      5d53b24de7f56061ea1f9585  R2CLQIHDGUI6TR
# 5      5d53b24de7f56061ea1f9586  R3CCE9NXE07U46
# 6      5d53b24de7f56061ea1f9587  R3SLM91EEAYEOJ
# 7      5d53b24de7f56061ea1f9588  R3E909V7N93QU7
# 8      5d53b24de7f56061ea1f9589   R837T97HK8XBD
# 9      5d53b24de7f56061ea1f958a   RDQSLQALENZDK
# 10     5d53b251e7f56061ea1f958b  R3IDWHR3OOLGCO
# 11     5d53b251e7f56061ea1f958c  R3ICWGKEPXZCCT
# 12     5d53b251e7f56061ea1f958d  R1UIL74YL71LLU
# 13     5d53b251e7f56061ea1f958e  R18LMMOY09BWGE
# 14     5d53b251e7f56061ea1f958f  R2Y59NTF8O76NU
# 15     5d53b251e7f56061ea1f9590  R3N0CJS1EJC3BQ
# 16     5d53b251e7f56061ea1f9591  R1DB0O4HFW4UMN
# 17     5d53b251e7f56061ea1f9592   R5EJCI6FDTITA
# 18     5d53b251e7f56061ea1f9593  R26K9X9JIKO1KA
# 19     5d53b251e7f56061ea1f9594  R22L5UI6HZ2FF3
# 20     5d53b257e7f56061ea1f9595  R1B4MK81I4G5JX
# 21     5d53b257e7f56061ea1f9596  R14MA3RS15S8GZ
# 22     5d53b257e7f56061ea1f9597  R2C1S496H8XIRB
# 23     5d53b257e7f56061ea1f9598  R3QWKKMU8CRBUD
# 24     5d53b257e7f56061ea1f9599  R1PX9Q3MSYUHHV
# 25     5d53b257e7f56061ea1f959a  R1BYERQX1FJSI9
# 26     5d53b257e7f56061ea1f959b  R3OI2KS1W0612P
# 27     5d53b257e7f56061ea1f959c  R2CQ0SH4J9O7AU
# 28     5d53b257e7f56061ea1f959d  R1ZBWPRIEVGBAW
# 29     5d53b257e7f56061ea1f959e  R2FAWEM8N8Y6VE
# ...                         ...             ...
# 35637  5d544e36ecec8830d1aef534  R1VY3INFFNJJ2M
# 35638  5d544e36ecec8830d1aef535  R2CXN423ELYU9G
# 35639  5d544e36ecec8830d1aef536  R3HL2FKK3P0WEG
# 35640  5d544e36ecec8830d1aef537  R3UA9MZVH5LHIN
# 35641  5d544e36ecec8830d1aef538  R1TWCYYKS6UGB1
# 35642  5d544e36ecec8830d1aef539  R1PG8CLM9BDLB2
# 35643  5d544e36ecec8830d1aef53a  R2WME4MG6FL947
# 35644  5d544e36ecec8830d1aef53b  R2CSETW0QUQ6XO
# 35645  5d544e36ecec8830d1aef53c  R3N2LSNODPGSDK
# 35646  5d544e36ecec8830d1aef53d  R119FCWKPG5RPG
# 35647  5d544e3aecec8830d1aef53e  R2UQ40Z1DZC3VV
# 35648  5d544e3aecec8830d1aef53f  R2T1ZQY0HBINHO
# 35649  5d544e3aecec8830d1aef540  R1HC72IBK3PAQ4
# 35650  5d544e3aecec8830d1aef541  R3TLVTGU8DTE7M
# 35651  5d544e3aecec8830d1aef542  R39YR913XVTA2H
# 35652  5d544e3aecec8830d1aef543  R1F1DR76KB1LN9
# 35653  5d544e3aecec8830d1aef544   RC4SBIU5IJ74K
# 35654  5d544e3aecec8830d1aef545  R2ZJR9PRAL6VE2
# 35655  5d544e3aecec8830d1aef546  R1AR92RVABYGW8
# 35656  5d544e3aecec8830d1aef547  R3TOF2XT76HE2B
# 35657  5d544e40ecec8830d1aef548  R1NVB152OJL2II
# 35658  5d544e40ecec8830d1aef549   RR289DYXE98ZK
# 35659  5d544e40ecec8830d1aef54a   R6AXMANBHDO8U
# 35660  5d544e40ecec8830d1aef54b   RH8HKT1PFAPX2
# 35661  5d544e40ecec8830d1aef54c  R1Z1JBLO1GDQQ7
# 35662  5d544e40ecec8830d1aef54d  R15EWYYKH5AT5I
# 35663  5d544e40ecec8830d1aef54e  R2KHZF5W9BAUVA
# 35664  5d544e40ecec8830d1aef54f   R3C5SDNRUDTP7
# 35665  5d544e40ecec8830d1aef550   RQMQEY8T71CEZ
# 35666  5d544e40ecec8830d1aef551   R75TSWDVTBUYC
#
#                                                   corpus
# 0                                              Good Good
# 1      Needed this memory card for my Action Camera. ...
# 2              I just got it today works good Works good
# 3      Samsung it’s really good quality Bought it for...
# 4      No Lamentablemente pedí que enviaran todos los...
# 5                                                  👍🏽 👍🏽
# 6                                           GOOD LIKE IT
# 7                Thank you very good Thank you very good
# 8      Very good product It is used to keep data out ...
# 9                                              bon merci
# 10                                   Great Buy Great buy
# 11     Memory card —— from 4 star amazon store I have...
# 12     Meets My Expectations I bought it for my new D...
# 13                                   Bueno Buena calidad
# 14           Great Great price on the card.  Works fine.
# 15     Great I ordered it for my security cameras and...
# 16     Very nice Very nice it actually has the room i...
# 17     great product Didn't had any issues, very sati...
# 18     Very nice MicroSD card Good price, fast read/w...
# 19     1 out of 4 stopped working immediatley Purchas...
# 20     Good price Had no issues. Very good price. I b...
# 21     nice As cheap as storage capacity is I don't u...
# 22                         Great value Using on my phone
# 23     Works as described. It works as described and ...
# 24                                             Nice Nice
# 25              Love it Works like charm and great price
# 26                 Good value works great in my dash cam
# 27                                     AWESOME I love it
# 28     Samsung 32 Came quickly, just as advertised. P...
# 29     Defective I bought this for a taotronics dash ...
# ...                                                  ...
# 35637  I like it. Works as expected.  No problems, go...
# 35638                                Five Stars Perfecto
# 35639  Five Stars Works great for my application, I u...
# 35640  Fast and add more storage to your phone It gav...
# 35641                excellent Fast service... excellent
# 35642  Three Stars A lot of space but very slow trans...
# 35643  My phone had a terrible problem with lagging w...
# 35644  64 GB doesn't work with SD card readers. Micro...
# 35645                          It was a gift. Great card
# 35646         Great price! Great value. Arrived quickly!
# 35647                   Five Stars whse deal price point
# 35648                 Five Stars Good card fast shipping
# 35649                              Five Stars Good Price
# 35650  Great! Awesome memory card! Works on Nintendo ...
# 35651          Four Stars Does what it is supposed to do
# 35652  Five Stars It worked on my switch just as adve...
# 35653  Four Stars Micro sd works, adaptador did notRe...
# 35654  Five Stars Works great for my Moto Z Force Dro...
# 35655  Not the first time I've ordered this. I needed...
# 35656    Five Stars works great with the Nintendo Switch
# 35657  It works great. SanDisk is very reliable It's ...
# 35658  45 GB so they stole like almost 5 GB It is not...
# 35659                good, and cheaper good, and cheaper
# 35660                                  Five Stars Gracia
# 35661               Five Stars the name bran says it all
# 35662                                   Five Stars Great
# 35663  Five Stars affordable way to triple the capaci...
# 35664  Works great. Exactly as listed. Works great. E...
# 35665          Works as advertised. Works as advertised.
# 35666  One Star It keep saying that I should format i...
#
# [35667 rows x 3 columns]

# %%
# pipeline =    [
#         { '$project': {'corpus': {'$concat': [ "$title", " ", "$content" ]}},
#          '$review_id': 1
#         }
#     ]

# corpus = list(db.project.reviews.aggregate(pipeline))

# %%
corpus
# Out:
# [{'_id': ObjectId('5d53b24de7f56061ea1f9581'), 'corpus': 'Good Good'},
#  {'_id': ObjectId('5d53b24de7f56061ea1f9582'),
#   'corpus': 'Needed this memory card for my Action Camera. Works great in my Full HD Action Camera. I highly recommend this memory card. :))'},
#  {'_id': ObjectId('5d53b24de7f56061ea1f9583'),
#   'corpus': 'I just got it today works good Works good'},
#  {'_id': ObjectId('5d53b24de7f56061ea1f9584'),
#   'corpus': 'Samsung it’s really good quality Bought it for a friend and really liked it'},
#  {'_id': ObjectId('5d53b24de7f56061ea1f9585'),
#   'corpus': 'No Lamentablemente pedí que enviaran todos los artículos en un solo paquete y no fue así.'},
#  {'_id': ObjectId('5d53b24de7f56061ea1f9586'), 'corpus': '👍🏽 👍🏽'},
#  {'_id': ObjectId('5d53b24de7f56061ea1f9587'), 'corpus': 'GOOD LIKE IT'},
#  {'_id': ObjectId('5d53b24de7f56061ea1f9588'),
#   'corpus': 'Thank you very good Thank you very good'},
#  {'_id': ObjectId('5d53b24de7f56061ea1f9589'),
#   'corpus': 'Very good product It is used to keep data out from my phone'},
#  {'_id': ObjectId('5d53b24de7f56061ea1f958a'), 'corpus': 'bon merci'},
#  {'_id': ObjectId('5d53b251e7f56061ea1f958b'),
#   'corpus': 'Great Buy Great buy'},
#  {'_id': ObjectId('5d53b251e7f56061ea1f958c'),
#   'corpus': 'Memory card —— from 4 star amazon store I have purchased this from a amazon 4 star store in Denver. The store was very busy and one of associate helped me find this memory card. Memory card copy speed is quite speed, and looks of very good quality. I can directly connect to my laptop with the adaptor included.'},
#  {'_id': ObjectId('5d53b251e7f56061ea1f958d'),
#   'corpus': 'Meets My Expectations I bought it for my new Dash Camera. No complaints.'},
#  {'_id': ObjectId('5d53b251e7f56061ea1f958e'),
#   'corpus': 'Bueno Buena calidad'},
#  {'_id': ObjectId('5d53b251e7f56061ea1f958f'),
#   'corpus': 'Great Great price on the card.  Works fine.'},
#  {'_id': ObjectId('5d53b251e7f56061ea1f9590'),
#   'corpus': 'Great I ordered it for my security cameras and it performed miraculously.'},
#  {'_id': ObjectId('5d53b251e7f56061ea1f9591'),
#   'corpus': 'Very nice Very nice it actually has the room it says it does and it works great on my phone.  It stays connected unlike my last memory card.  I finally have enough room for all my games and photos, will probably get another for my tablet.'},
#  {'_id': ObjectId('5d53b251e7f56061ea1f9592'),
#   'corpus': "great product Didn't had any issues, very satisfied!"},
#  {'_id': ObjectId('5d53b251e7f56061ea1f9593'),
#   'corpus': 'Very nice MicroSD card Good price, fast read/write speed. Overall good value!'},
#  {'_id': ObjectId('5d53b251e7f56061ea1f9594'),
#   'corpus': '1 out of 4 stopped working immediatley Purchased for use in Yi home cameras. Three of them worked fine, the fourth cannot be read or accessed by the camera or a card reader.'},
#  {'_id': ObjectId('5d53b257e7f56061ea1f9595'),
#   'corpus': 'Good price Had no issues. Very good price. I bought it for a dash cam but 32gb is not enough storage to record video in 720p. Barely 3 hours of total video. so I bought a another one that’s 256gb.'},
#  {'_id': ObjectId('5d53b257e7f56061ea1f9596'),
#   'corpus': "nice As cheap as storage capacity is I don't understand why it's so expensive in devices already. It's confusing how extra storage works how you can't save the same stuff on it as you can your device?"},
#  {'_id': ObjectId('5d53b257e7f56061ea1f9597'),
#   'corpus': 'Great value Using on my phone'},
#  {'_id': ObjectId('5d53b257e7f56061ea1f9598'),
#   'corpus': 'Works as described. It works as described and doing its job well.'},
#  {'_id': ObjectId('5d53b257e7f56061ea1f9599'), 'corpus': 'Nice Nice'},
#  {'_id': ObjectId('5d53b257e7f56061ea1f959a'),
#   'corpus': 'Love it Works like charm and great price'},
#  {'_id': ObjectId('5d53b257e7f56061ea1f959b'),
#   'corpus': 'Good value works great in my dash cam'},
#  {'_id': ObjectId('5d53b257e7f56061ea1f959c'), 'corpus': 'AWESOME I love it'},
#  {'_id': ObjectId('5d53b257e7f56061ea1f959d'),
#   'corpus': 'Samsung 32 Came quickly, just as advertised. Packed great. Helps a lot with my wife’s phone'},
#  {'_id': ObjectId('5d53b257e7f56061ea1f959e'),
#   'corpus': 'Defective I bought this for a taotronics dash cam.  Immediately after putting it in the dash cam It continues to loop as of the card is full.I’m assuming its  defective'},
#  {'_id': ObjectId('5d53b2918c0d3676e4d045eb'),
#   'corpus': 'Died after 1 year Ordered on November 17, 2018 for my Raspberry Pi 3. As of August 2019, its fried. Cannot get it to read on the raspberry Pi or any computer I have. Would not recommend it for any use where you have slightly higher read/write.'},
#  {'_id': ObjectId('5d53b2918c0d3676e4d045ec'),
#   'corpus': 'Worked great I got this to use in an off brand action camera. It works great but minimal usage so far.'},
#  {'_id': ObjectId('5d53b2918c0d3676e4d045ed'),
#   'corpus': 'Fast service Enough space for my dash cam and it came fast'},
#  {'_id': ObjectId('5d53b2918c0d3676e4d045ee'),
#   'corpus': 'I like it Great MicroSD, works flawlessly'},
#  {'_id': ObjectId('5d53b2918c0d3676e4d045ef'),
#   'corpus': 'Works well in a camera I got this to use in my Cannon Camera and it has worked great so far.'},
#  {'_id': ObjectId('5d53b2918c0d3676e4d045f0'),
#   'corpus': 'strong! Perfectly~ Thank you~'},
#  {'_id': ObjectId('5d53b2918c0d3676e4d045f1'),
#   'corpus': 'Use in the UAV I use this card in my UAV for photos great.'},
#  {'_id': ObjectId('5d53b2918c0d3676e4d045f2'), 'corpus': 'Good Good'},
#  {'_id': ObjectId('5d53b2918c0d3676e4d045f3'),
#   'corpus': 'Me gusto Buena calidad'},
#  {'_id': ObjectId('5d53b2918c0d3676e4d045f4'),
#   'corpus': 'Great value. Great value, great quality.  no issues.  comes with SD card adapter'},
#  {'_id': ObjectId('5d53b2938c0d3676e4d045f5'),
#   'corpus': 'Quick & easy to install. Easy to use'},
#  {'_id': ObjectId('5d53b2938c0d3676e4d045f6'),
#   'corpus': 'Never leave them in your clothes’ pockets, NEVER! It was perfect for my dash cam... until I removed it, yet again, to take out a video with my iPhone (using that weird name adapter) and... I got a call, so I took the memory card and put it on my shirt pocket... call took forever, so I placed my glasses on the same pocket...Long story short I forgot about it... and the next day my wife did the laundry and, well nobody could have seen the card inside the shirt pocket... so who knows where it is now: drain? Or inside the Maytag washing machine?? LOLI had a good road rage moment there and wanted to share on YouTube... sad! He he'},
#  {'_id': ObjectId('5d53b2938c0d3676e4d045f7'),
#   'corpus': 'great value for my project use -- Thanks ...'},
#  {'_id': ObjectId('5d53b2938c0d3676e4d045f8'),
#   'corpus': "Works fine,  no failures in several years of use Purchased for a raspberry pi and ran without issue for several years.  Bought this one given the consistent behavior of the previous one purchased.  At under $0.25 cents per gb they're great value for the money."},
#  {'_id': ObjectId('5d53b2938c0d3676e4d045f9'),
#   'corpus': 'Very satisfied It does the job.'},
#  {'_id': ObjectId('5d53b2938c0d3676e4d045fa'),
#   'corpus': 'Good product Good product'},
#  {'_id': ObjectId('5d53b2938c0d3676e4d045fb'), 'corpus': 'Good Good'},
#  {'_id': ObjectId('5d53b2938c0d3676e4d045fc'),
#   'corpus': 'No fuss Micro SD Card for Dash Cam!! Love it! Nothing bad to say about the Micro SD Card. Bought 2 32GB for two dash cams. Easy to format and use.'},
#  {'_id': ObjectId('5d53b2938c0d3676e4d045fd'),
#   'corpus': 'Great storage. Works perfect.'},
#  {'_id': ObjectId('5d53b2938c0d3676e4d045fe'),
#   'corpus': 'Sweet spot This is my go to for microSD cards.  For a few pennies more that the generic ones, you get more speed and capacity.'},
#  {'_id': ObjectId('5d53b2978c0d3676e4d045ff'),
#   'corpus': 'Works It’s doing what it supposed to do so thansks seller'},
#  {'_id': ObjectId('5d53b2978c0d3676e4d04600'),
#   'corpus': 'Easy to setup Works great'},
#  {'_id': ObjectId('5d53b2978c0d3676e4d04601'), 'corpus': 'A++++ A+++++'},
#  {'_id': ObjectId('5d53b2978c0d3676e4d04602'),
#   'corpus': 'Works great Works good bought 4 two for each camera one for my watch and one for my phone works great'},
#  {'_id': ObjectId('5d53b2978c0d3676e4d04603'),
#   'corpus': 'Good price Good qaulity'},
#  {'_id': ObjectId('5d53b2978c0d3676e4d04604'),
#   'corpus': "Great for SBCs I've been running this in my Tinkerboard (Single Board Computer kind of like a Raspberry Pi) and it's been doing great, I've went through a lot of different SD cards for Pis and eventually they would corrupt and not boot, this has been running steady for almost 2 years now. The read/write speeds are great for this application and I'm running a webserver on it (serving 2 domains) so it's reading files a lot and serving them up."},
#  {'_id': ObjectId('5d53b2978c0d3676e4d04605'),
#   'corpus': "Great quality.  Has been working well. Bought this more local storage on my Roku 3, which has recently complained of needing more storage space to improve app performance.  Can always use this chip in another device when the Roku 3 gives its last dying breath.  Samsung is a reliably made product, and I don't expect to have to exercise the warranty.  Can't beat the price at $7.99."},
#  {'_id': ObjectId('5d53b2978c0d3676e4d04606'),
#   'corpus': 'Gift Bought as gift'},
#  {'_id': ObjectId('5d53b2978c0d3676e4d04607'),
#   'corpus': 'Great value Great for its purpose. Got cameras and they fit perfectly.'},
#  {'_id': ObjectId('5d53b2978c0d3676e4d04608'), 'corpus': 'Easy Great'},
#  {'_id': ObjectId('5d53b2998c0d3676e4d04609'),
#   'corpus': 'Good product . A happy customer Good product , works as expected. Thank you'},
#  {'_id': ObjectId('5d53b2998c0d3676e4d0460a'),
#   'corpus': "Reliable, very worth its money I'm geeky enthusiast, using SD cards for many needs. Tried number of brands, many types of cards. This one has the best price/value ratio. Value is a mix of performance and reliability."},
#  {'_id': ObjectId('5d53b2998c0d3676e4d0460b'),
#   'corpus': 'works well good deal works well good deal'},
#  {'_id': ObjectId('5d53b2998c0d3676e4d0460c'),
#   'corpus': 'These are amazing! Works as described!'},
#  {'_id': ObjectId('5d53b2998c0d3676e4d0460d'),
#   'corpus': 'Top performance and great value These samsung EVO and PRO microSD cards always come out on top when people test them for transfer speed and particularly random read access speed even amongst the best manufacturers.  The difference between a great card like these and a low quality card can mean a 10-fold difference in usable performance if you expect to repeatedly write and read from it.'},
#  {'_id': ObjectId('5d53b2998c0d3676e4d0460e'),
#   'corpus': 'Make sure to choose the correct card My first purchase was for a regular sd card, I thought it was a micro sd card in a regular sd card cassete. After finding out my mistake and bought this card.  No problems in my phone!'},
#  {'_id': ObjectId('5d53b2998c0d3676e4d0460f'),
#   'corpus': 'Excelente cumplió con lo indicado Excelente cumplió con lo indicado'},
#  {'_id': ObjectId('5d53b2998c0d3676e4d04610'),
#   'corpus': 'Samsung memory performs as designed'},
#  {'_id': ObjectId('5d53b2998c0d3676e4d04611'),
#   'corpus': 'Legit I got this micro sdcard on sale day for my garmin. Yeah very cheap vs the quality and performance.'},
#  {'_id': ObjectId('5d53b2998c0d3676e4d04612'),
#   'corpus': "SD cards of SD size It's what I needed so it's what I got!  No issues!"},
#  {'_id': ObjectId('5d53b29e8c0d3676e4d04613'),
#   'corpus': 'Perfect for my 4k dash cams Use it for my dash cams and it works great!'},
#  {'_id': ObjectId('5d53b29e8c0d3676e4d04614'),
#   'corpus': 'Good enough Ok for money'},
#  {'_id': ObjectId('5d53b29e8c0d3676e4d04615'),
#   'corpus': 'Good value Great product'},
#  {'_id': ObjectId('5d53b29e8c0d3676e4d04616'),
#   'corpus': 'Good Quality, Works Great For What I Need Not much to say about an SD card but it works perfectly. I bought this to replace my 8gb one I had in my dash cam. Been about a week and so far so good.'},
#  {'_id': ObjectId('5d53b29e8c0d3676e4d04617'),
#   'corpus': "You won't be sorry that you tried this A heck of a good deal and I was so happy I purchased"},
#  {'_id': ObjectId('5d53b29e8c0d3676e4d04618'),
#   'corpus': 'Good Worked as expected'},
#  {'_id': ObjectId('5d53b29e8c0d3676e4d04619'),
#   'corpus': 'Solid performance and great price Great value. Purchased 2 of these. 1 for each of my daughters tablets. They are happy with the extra room for movies and games.'},
#  {'_id': ObjectId('5d53b29e8c0d3676e4d0461a'),
#   'corpus': 'Go Samsung I just believe that Samsung is the number one brand when it comes to data storage. Also, good value for the money.'},
#  {'_id': ObjectId('5d53b29e8c0d3676e4d0461b'),
#   'corpus': 'Excellent product!! Excellent product!!'},
#  {'_id': ObjectId('5d53b29e8c0d3676e4d0461c'),
#   'corpus': "Great storage card Does what its supposed to storing images on our Cannon camera.  We've had issues in the past with the camera being unable to format cards from other companies.  This one worked flawlessly."},
#  {'_id': ObjectId('5d53b2a48c0d3676e4d0461d'), 'corpus': 'Thanks Super'},
#  {'_id': ObjectId('5d53b2a48c0d3676e4d0461e'),
#   'corpus': 'Brand name Not quite 32 only shows 30'},
#  {'_id': ObjectId('5d53b2a48c0d3676e4d0461f'),
#   'corpus': 'Works great with my tablet Great space capacity'},
#  {'_id': ObjectId('5d53b2a48c0d3676e4d04620'),
#   'corpus': 'Samsung always a good value If your phone has an upper tolerable storage limit of 32GB, no reason not to go with this Samsung. Works okay. If your phone can format an SD card as internal, you can use this for apps. Though that is becoming less of an option these days for whatever reason. (Probably $$).'},
#  {'_id': ObjectId('5d53b2a48c0d3676e4d04621'),
#   'corpus': 'Awesome Easy, fast and reliable.'},
#  {'_id': ObjectId('5d53b2a48c0d3676e4d04622'),
#   'corpus': 'Easy to use Working very great and just glad I can free up my phone thanks'},
#  {'_id': ObjectId('5d53b2a48c0d3676e4d04623'),
#   'corpus': 'FAKE CARD!!! I bought the 32 Gb card for a rasberry pi, but when going to flash the image the card shows up as 4.3 Gb! These are not real micro sd cards.'},
#  {'_id': ObjectId('5d53b2a48c0d3676e4d04624'),
#   'corpus': 'Works great in Dashcams I bought this for installation in a dashcam. It works fine and I have not had any issues since purchasing it 6+ months ago.'},
#  {'_id': ObjectId('5d53b2a48c0d3676e4d04625'),
#   'corpus': "Does what it's supposed to for a good price Cheap and reliable."},
#  {'_id': ObjectId('5d53b2a48c0d3676e4d04626'),
#   'corpus': "Great speed This card perform well. Consider that most of this cards are formatted as FAT32 by default. This will won't allow you to transfer files over 4GB. So Formatting exFAT will handle this.  Be aware that some vendors sell fake SD cards so get it from a reputable vendor."},
#  {'_id': ObjectId('5d53b330607e5e5c7218fa12'), 'corpus': 'SIM card Perfect'},
#  {'_id': ObjectId('5d53b330607e5e5c7218fa13'),
#   'corpus': 'Affordable Samsung SD card Great quality SD Card...'},
#  {'_id': ObjectId('5d53b330607e5e5c7218fa14'), 'corpus': 'So so So so'},
#  {'_id': ObjectId('5d53b330607e5e5c7218fa15'),
#   'corpus': 'La mejor Muy buenas'},
#  {'_id': ObjectId('5d53b330607e5e5c7218fa16'),
#   'corpus': 'Will withstand the heat of Texas summer. This card proves to work in high temperature climate of Texas, whereas other cards literally burned in operation. I use it for a dashcam that seats attached to my windshield, so it has proven to be a test bed for these sd cards. Samsung truly delivers in this case, and will serve me well for years to come.'},
#  {'_id': ObjectId('5d53b330607e5e5c7218fa17'), 'corpus': 'good good'},
#  {'_id': ObjectId('5d53b330607e5e5c7218fa18'),
#   'corpus': 'Compatible with different brands of cellphones Good quality and good price'},
#  {'_id': ObjectId('5d53b330607e5e5c7218fa19'),
#   'corpus': 'Perfect Great product, worked as advertised.'},
#  {'_id': ObjectId('5d53b330607e5e5c7218fa1a'),
#   'corpus': 'Por el precio, buen producto EXCELENTE'},
#  {'_id': ObjectId('5d53b330607e5e5c7218fa1b'),
#   'corpus': 'Just like the picture Just like the picture'},
#  {'_id': ObjectId('5d53b334607e5e5c7218fa1c'),
#   'corpus': 'Storage Heaven The only thing cheap about the Samsung 32GB microSDHC EVO select memory card is the price. The durability is amazing.The ones I use to use would get scratched & crack over a short period of time but not this one. Its the best Of the best and I use it a lost ,from phone to computer,from computer to phone daily and it works like it did when I first got it.. Highly Recommend It'},
#  {'_id': ObjectId('5d53b334607e5e5c7218fa1d'),
#   'corpus': 'Excellent Very good'},
#  {'_id': ObjectId('5d53b334607e5e5c7218fa1e'),
#   'corpus': 'Is as described. Good quality. Did what it was supposed to. No problems.'},
#  {'_id': ObjectId('5d53b334607e5e5c7218fa1f'),
#   'corpus': 'Good product Good product'},
#  {'_id': ObjectId('5d53b334607e5e5c7218fa20'),
#   'corpus': 'perfect for the price I am very pleased with this Prime Day purchase.  It is exactly what I wanted and for a fraction of what I would normally have to pay.'},
#  {'_id': ObjectId('5d53b334607e5e5c7218fa21'), 'corpus': 'Yes Works'},
#  {'_id': ObjectId('5d53b334607e5e5c7218fa22'),
#   'corpus': 'Great memory cards, work excellent. These cards work perfect for my video cams, they are super fast and have the advertised capacity of 32gb.'},
#  {'_id': ObjectId('5d53b334607e5e5c7218fa23'),
#   'corpus': 'Easy Peasy! Great memory cards. I used these in my WYZE cameras. Plug and play was the order of the day. Love them!!!'},
#  {'_id': ObjectId('5d53b334607e5e5c7218fa24'), 'corpus': 'Perfect Awesome'},
#  {'_id': ObjectId('5d53b334607e5e5c7218fa25'),
#   'corpus': 'Does what it promises OEM product'},
#  {'_id': ObjectId('5d53b338607e5e5c7218fa26'), 'corpus': 'Car Nice'},
#  {'_id': ObjectId('5d53b338607e5e5c7218fa27'),
#   'corpus': 'considerable capacity very good response speed'},
#  {'_id': ObjectId('5d53b338607e5e5c7218fa28'),
#   'corpus': 'great for cameras using this  to capture  4k footage was no problem at all . great price  I cant complain .'},
#  {'_id': ObjectId('5d53b338607e5e5c7218fa29'),
#   'corpus': 'Excelente! Excelente!'},
#  {'_id': ObjectId('5d53b338607e5e5c7218fa2a'),
#   'corpus': 'Good branch storage card I just a storage Card, Samsung have a good branch of products.'},
#  {'_id': ObjectId('5d53b338607e5e5c7218fa2b'),
#   'corpus': 'All good Works well'},
#  {'_id': ObjectId('5d53b338607e5e5c7218fa2c'),
#   'corpus': 'Very good Bought to use with the camera, very good.'},
#  {'_id': ObjectId('5d53b338607e5e5c7218fa2d'),
#   'corpus': 'FIVE STARS avoiding extra words, Samsung quality'},
#  {'_id': ObjectId('5d53b338607e5e5c7218fa2e'), 'corpus': 'Good Good price'},
#  {'_id': ObjectId('5d53b338607e5e5c7218fa2f'),
#   'corpus': 'You get what you Pay for I bought this Samsung Evo 32GB for my GoPro and my Digicam.  It perform better than what its rated, V10 and U1 class 10 spec has a minimum write speed of at least 10 Mbyte/s, which is what you need for 1080p recording.  I ran several SD card speed test with my computer and I get a speed on average of 35Mb/s Write and 92 Mb/s read.  At over 30Mb/s this card should be rated v30 and U3, also to note over 30mb/s minimum is 4K HD video recording ready....'},
#  {'_id': ObjectId('5d53b33e607e5e5c7218fa30'),
#   'corpus': 'Good quality Good for my GPS'},
#  {'_id': ObjectId('5d53b33e607e5e5c7218fa31'), 'corpus': 'Good Like'},
#  {'_id': ObjectId('5d53b33e607e5e5c7218fa32'),
#   'corpus': 'Corrupted after 1 week Data corrupted after 1 week usage in Home camera.'},
#  {'_id': ObjectId('5d53b33e607e5e5c7218fa33'),
#   'corpus': 'No me ha llegado No me ha llegado dice en el rastreo que llegó pero en mi buzón nunca apareció hasta la fecha'},
#  {'_id': ObjectId('5d53b33e607e5e5c7218fa34'),
#   'corpus': 'Works Great! Works as advertised, used in Smart Camera 360. No complaints'},
#  {'_id': ObjectId('5d53b33e607e5e5c7218fa35'),
#   'corpus': 'Serves its purpose, Decent price Not much to say serves its purpose. Works well'},
#  {'_id': ObjectId('5d53b33e607e5e5c7218fa36'),
#   'corpus': "Quality, budget friendly Can't go wrong with a Samsung drive nomatter what it is"},
#  {'_id': ObjectId('5d53b33e607e5e5c7218fa37'),
#   'corpus': 'Great deal!! Very happy with this purchase!!'},
#  {'_id': ObjectId('5d53b33e607e5e5c7218fa38'),
#   'corpus': 'best of best best of best'},
#  {'_id': ObjectId('5d53b33e607e5e5c7218fa39'),
#   'corpus': 'Does what it should Works great for car dvr.'},
#  {'_id': ObjectId('5d53b344607e5e5c7218fa3a'),
#   'corpus': 'Great product, good price Great product'},
#  {'_id': ObjectId('5d53b344607e5e5c7218fa3b'),
#   'corpus': 'Phone disk Keeps all the xtra in the phone'},
#  {'_id': ObjectId('5d53b344607e5e5c7218fa3c'),
#   'corpus': 'Fast memory card Fast memory nice transfer speeds. The price was also right.'},
#  {'_id': ObjectId('5d53b344607e5e5c7218fa3d'),
#   'corpus': 'Just what I wanted ! Lots of storage for my security camers.'},
#  {'_id': ObjectId('5d53b344607e5e5c7218fa3e'),
#   'corpus': "Great So far works really good in my Samsung Galaxy s9 plus hasn't lost any pitchers or files like the sandisk one I had"},
#  {'_id': ObjectId('5d53b344607e5e5c7218fa3f'),
#   'corpus': 'Exactly as advertised Been in service for some time now and works EXACTLY as advertised. Good value purchase. Thank you Amazon.'},
#  {'_id': ObjectId('5d53b344607e5e5c7218fa40'),
#   'corpus': 'Works great. Works great.'},
#  {'_id': ObjectId('5d53b344607e5e5c7218fa41'),
#   'corpus': 'Great sd card for the money. Product received as described.  Works great.'},
#  {'_id': ObjectId('5d53b344607e5e5c7218fa42'), 'corpus': 'Quality Very good'},
#  {'_id': ObjectId('5d53b344607e5e5c7218fa43'),
#   'corpus': 'Works Works as expected.'},
#  {'_id': ObjectId('5d53b349607e5e5c7218fa44'),
#   'corpus': 'Good car camera is what is said to buy works good let you know when to format'},
#  {'_id': ObjectId('5d53b349607e5e5c7218fa45'),
#   'corpus': 'Works well Memory expansion.'},
#  {'_id': ObjectId('5d53b349607e5e5c7218fa46'),
#   'corpus': "That's What It Is! I ordered the 32 gig micro SD card. I got exactly 32 gigs. Not 30 or 31 or even 33. If precision is important to you, then getting the exact number of gigs you ordered is important. Rest assured that you get 32 gigs with this card. It is also actually in micro SD format. So there's that. And It's got a recognizable brand name. Don't ever trust a BillyBob 30+g(ish) small(ish) memory card thing."},
#  {'_id': ObjectId('5d53b349607e5e5c7218fa47'), 'corpus': 'good good'},
#  {'_id': ObjectId('5d53b349607e5e5c7218fa48'),
#   'corpus': 'No problem for dash camera I use this card for my dash camera. Everything works as expected. No problem at all so far.'},
#  {'_id': ObjectId('5d53b349607e5e5c7218fa49'),
#   'corpus': 'Works as advertised Works as described and what was expected.  What more is there to say.'},
#  {'_id': ObjectId('5d53b349607e5e5c7218fa4a'),
#   'corpus': 'Great added memory Installed in a Samsung phone. Works great.'},
#  {'_id': ObjectId('5d53b349607e5e5c7218fa4b'),
#   'corpus': 'Good Product Good product'},
#  {'_id': ObjectId('5d53b349607e5e5c7218fa4c'),
#   'corpus': 'Samsung great I always buy Samsung cards, never had a problem'},
#  {'_id': ObjectId('5d53b349607e5e5c7218fa4d'),
#   'corpus': 'Good for the value! Good for the value'},
#  {'_id': ObjectId('5d53b34d607e5e5c7218fa4e'),
#   'corpus': 'Bien para lo que la necesito Todo muy bien la compre para la cámara yi y queda perfect'},
#  {'_id': ObjectId('5d53b34d607e5e5c7218fa4f'),
#   'corpus': 'Works great Fits a ton of roms for retropie'},
#  {'_id': ObjectId('5d53b34d607e5e5c7218fa50'),
#   'corpus': 'Perfect! Works well and since I got it on prime day it was super cheap!! I use this on my GoPro session 5 to record at 2.7k & 30fps'},
#  {'_id': ObjectId('5d53b34d607e5e5c7218fa51'),
#   'corpus': 'nice!!!!!!!!!!! Great product!!!!!!!!'},
#  {'_id': ObjectId('5d53b34d607e5e5c7218fa52'),
#   'corpus': 'Great dash cam Great dash cam'},
#  {'_id': ObjectId('5d53b34d607e5e5c7218fa53'),
#   'corpus': 'good product, fast shipping. Thanks. good product, fast shipping. Thanks.'},
#  {'_id': ObjectId('5d53b34d607e5e5c7218fa54'),
#   'corpus': 'No brainer Why you reading this? Look at the price. Look at the brand. Uhhh awesome!'},
#  {'_id': ObjectId('5d53b34d607e5e5c7218fa55'),
#   'corpus': 'No problems Exactly what I needed, for a dash camera.'},
#  {'_id': ObjectId('5d53b34d607e5e5c7218fa56'),
#   'corpus': 'Es muy rápido el envió recomendado la menbrecia prime Es lo que pedí muy buen producto'},
#  {'_id': ObjectId('5d53b34d607e5e5c7218fa57'),
#   'corpus': 'Good Purchase Works with Vimtag indoor camera. Stores memory and is a good value.'},
#  {'_id': ObjectId('5d53b352607e5e5c7218fa58'),
#   'corpus': 'Reliability counts Fast shipping, good product'},
#  {'_id': ObjectId('5d53b352607e5e5c7218fa59'),
#   'corpus': 'Perfect It’s perfect'},
#  {'_id': ObjectId('5d53b352607e5e5c7218fa5a'),
#   'corpus': 'Grate It was a perfect for my phone and it has so much capacity. The price was perfect it works well and fast'},
#  {'_id': ObjectId('5d53b352607e5e5c7218fa5b'),
#   'corpus': 'Great price and works very well Works great and a very good price'},
#  {'_id': ObjectId('5d53b352607e5e5c7218fa5c'),
#   'corpus': 'Does the job The best memory stick makes you forget about it - it should be drama free.  This certainly fits the bill.'},
#  {'_id': ObjectId('5d53b352607e5e5c7218fa5d'),
#   'corpus': 'Happy customer Seems durable, trusted name brand'},
#  {'_id': ObjectId('5d53b352607e5e5c7218fa5e'),
#   'corpus': 'Expected Excellent product'},
#  {'_id': ObjectId('5d53b352607e5e5c7218fa5f'),
#   'corpus': 'Great salesperson great items That what the items Looks like online be what i get when delivered.and it was with no problems great salesperson'},
#  {'_id': ObjectId('5d53b352607e5e5c7218fa60'),
#   'corpus': 'I won’t suggest Broke down to quick'},
#  {'_id': ObjectId('5d53b352607e5e5c7218fa61'),
#   'corpus': 'You can never have many of these Got these on a deal on Amazon prime, I already have a bunch of them and they work great, fast, keep my data safe, easy to connect comes with an adapter too, I have a USB 3 adapter as well so these are my thumb drive as well.'},
#  {'_id': ObjectId('5d53b355607e5e5c7218fa62'),
#   'corpus': 'Failed a year after purchase Be careful, these are not reliable at all'},
#  {'_id': ObjectId('5d53b355607e5e5c7218fa63'),
#   'corpus': 'Funciona Eso, funciona'},
#  {'_id': ObjectId('5d53b355607e5e5c7218fa64'),
#   'corpus': 'Excelent ! Excelent purchase! Recommended!'},
#  {'_id': ObjectId('5d53b355607e5e5c7218fa65'),
#   'corpus': 'Best quality, best value Best quality card for the money! We’ve had many of these for our security cameras. They work and they last.'},
#  {'_id': ObjectId('5d53b355607e5e5c7218fa66'),
#   'corpus': 'Can’t Formont FORMAT FAIL!We apologize but Amazon is not accepting reviews on this product from this account. If you would like to contact us about this decision, please email community-help@amazon.com.'},
#  {'_id': ObjectId('5d53b355607e5e5c7218fa67'),
#   'corpus': 'Excellent Excellent'},
#  {'_id': ObjectId('5d53b355607e5e5c7218fa68'),
#   'corpus': 'Nice! Works well with my dash cam!'},
#  {'_id': ObjectId('5d53b355607e5e5c7218fa69'),
#   'corpus': 'It’s working fine Works well and it’s real'},
#  {'_id': ObjectId('5d53b355607e5e5c7218fa6a'),
#   'corpus': 'It works perfectly Love it'},
#  {'_id': ObjectId('5d53b355607e5e5c7218fa6b'), 'corpus': 'Ok Ok'},
#  {'_id': ObjectId('5d53b35c607e5e5c7218fa6c'), 'corpus': 'Works fine. Good'},
#  {'_id': ObjectId('5d53b35c607e5e5c7218fa6d'), 'corpus': 'Love it Thank you'},
#  {'_id': ObjectId('5d53b35c607e5e5c7218fa6e'),
#   'corpus': 'Not worth it. Product stopped working after 6 months'},
#  {'_id': ObjectId('5d53b35c607e5e5c7218fa6f'), 'corpus': 'Not work Weak'},
#  {'_id': ObjectId('5d53b35c607e5e5c7218fa70'),
#   'corpus': 'Quality It does the job.'},
#  {'_id': ObjectId('5d53b35c607e5e5c7218fa71'),
#   'corpus': 'Great deal for the money Samsung makes quality cards for a good price.'},
#  {'_id': ObjectId('5d53b35c607e5e5c7218fa72'),
#   'corpus': 'Pretty good MicroSD card Pretty good MicroSD card for its price. Speed is almost as was promised by vendor.Read speed up to 100.Write speed suppose to be up to 20MBs. In reality even faster! Around 30~33'},
#  {'_id': ObjectId('5d53b35c607e5e5c7218fa73'),
#   'corpus': 'no camera no need useless without a camera'},
#  {'_id': ObjectId('5d53b35c607e5e5c7218fa74'),
#   'corpus': 'Excelent product Excelent product'},
#  {'_id': ObjectId('5d53b35c607e5e5c7218fa75'),
#   'corpus': 'Life is a bit short Unfortunately, it has been unable to read and break.'},
#  {'_id': ObjectId('5d53b360607e5e5c7218fa76'),
#   'corpus': 'Lo recomiendo Muy buena'},
#  {'_id': ObjectId('5d53b360607e5e5c7218fa77'), 'corpus': 'Works Does the job'},
#  {'_id': ObjectId('5d53b360607e5e5c7218fa78'),
#   'corpus': 'Not working Not recommended if u r looking for your dashcam. Not looping, you have to delete all files and put it back in the camera.'},
#  {'_id': ObjectId('5d53b360607e5e5c7218fa79'),
#   'corpus': 'It’s stores stuff Great value for the money. Use this for our vlogging camera'},
#  {'_id': ObjectId('5d53b360607e5e5c7218fa7a'),
#   'corpus': 'needed a micro Sd for my car for music mixes. Works flawless for that app So yeah 5 stars. I mean it could be faster but I only load up a single use for music mixes that I rarely change. So good to go. No reason to knock a star off for my use.'},
#  {'_id': ObjectId('5d53b360607e5e5c7218fa7b'),
#   'corpus': 'Es buena Es buena un poco cara pero buena'},
#  {'_id': ObjectId('5d53b360607e5e5c7218fa7c'),
#   'corpus': 'Excelente Muy buena'},
#  {'_id': ObjectId('5d53b360607e5e5c7218fa7d'),
#   'corpus': 'Works Works great. I have had time where it doesn’t work but thinking it’s my camera. If I knew for sure I would give it 5 stars'},
#  {'_id': ObjectId('5d53b360607e5e5c7218fa7e'),
#   'corpus': 'Nice item Reasonable price.'},
#  {'_id': ObjectId('5d53b360607e5e5c7218fa7f'),
#   'corpus': 'No issues Using it with my Samsung Galaxy S7. Works great.'},
#  {'_id': ObjectId('5d53b362607e5e5c7218fa80'),
#   'corpus': 'Velocidad Capacidad y velocidad'},
#  {'_id': ObjectId('5d53b362607e5e5c7218fa81'),
#   'corpus': "Don't hesitate. It's worth it. This product has so...much storage."},
#  {'_id': ObjectId('5d53b362607e5e5c7218fa82'),
#   'corpus': 'Good deal Need these for home cameras. Couldn’t beat the price!'},
#  {'_id': ObjectId('5d53b362607e5e5c7218fa83'),
#   'corpus': 'Works as intended. Purchased for additional storage for a GPS unit. Works well and info is quickly accessible.'},
#  {'_id': ObjectId('5d53b362607e5e5c7218fa84'),
#   'corpus': 'No problems so far Works as advertised'},
#  {'_id': ObjectId('5d53b362607e5e5c7218fa85'),
#   'corpus': 'Okay product Worked. More storage capacity'},
#  {'_id': ObjectId('5d53b362607e5e5c7218fa86'),
#   'corpus': 'Great price Great price for a very good product.'},
#  {'_id': ObjectId('5d53b362607e5e5c7218fa87'),
#   'corpus': 'Excelente Articulo! Tal cual lo ordenado!'},
#  {'_id': ObjectId('5d53b362607e5e5c7218fa88'),
#   'corpus': 'Works I like that this works so well with my camera.'},
#  {'_id': ObjectId('5d53b362607e5e5c7218fa89'),
#   'corpus': 'Sd card Works great'},
#  {'_id': ObjectId('5d53b368607e5e5c7218fa8a'), 'corpus': 'Good Good'},
#  {'_id': ObjectId('5d53b368607e5e5c7218fa8b'),
#   'corpus': 'Exactly as described It does the job'},
#  {'_id': ObjectId('5d53b368607e5e5c7218fa8c'),
#   'corpus': "I'm a repeat buyer! I use these SD cards for camera, phones and tablets. They work great! I have bought others that were preloaded with junk, which was a disappointment since one even caused a virus on my laptop. So, I stick with these because they have yet to fail me."},
#  {'_id': ObjectId('5d53b368607e5e5c7218fa8d'),
#   'corpus': "Good Security 's camera"},
#  {'_id': ObjectId('5d53b368607e5e5c7218fa8e'),
#   'corpus': 'Micro-SD Card Bought for phone.Fast. Cheap.'},
#  {'_id': ObjectId('5d53b368607e5e5c7218fa8f'),
#   'corpus': "Reliable and good value I got this card to use with a Wyze cam, and it's been working great for months. It gets written to every day so this is a hard application, where I would expect a crappy card to give in soon enough. No problems so far."},
#  {'_id': ObjectId('5d53b368607e5e5c7218fa90'),
#   'corpus': 'Great price !! Great!'},
#  {'_id': ObjectId('5d53b368607e5e5c7218fa91'),
#   'corpus': "GREAT PRODUCT Short and sweet review.  Great micro SD card and comes with an micro SD to SD reader so that's always helpful."},
#  {'_id': ObjectId('5d53b368607e5e5c7218fa92'), 'corpus': '👍 👍'},
#  {'_id': ObjectId('5d53b368607e5e5c7218fa93'),
#   'corpus': 'Didnt work for me Was not able to put anything on the card!'},
#  {'_id': ObjectId('5d53b36f607e5e5c7218fa94'), 'corpus': 'Honesty Just fine'},
#  {'_id': ObjectId('5d53b36f607e5e5c7218fa95'),
#   'corpus': 'memery card works  good'},
#  {'_id': ObjectId('5d53b36f607e5e5c7218fa96'),
#   'corpus': 'Great memory card I like these cards, especially because it is white. I know that might sound silly, but when you drop it between your car seats, and its black, it is very tough find. I have a couple from a brick and mortar location, that were very similar, and came looking for those. (they look the same but have a yellow bar instead of green one like there.They work fine, and I plan to start replacing my cards. with these as needed.A good tip you might want to follow is to buy the MicroSD with adapter, instead of a standard SD card, even if your device uses a SD card. The reason is, if you break the SD card, you will lose data. The MicroSD is very hard to break, and cn be swapped with a different adapter if needed.'},
#  {'_id': ObjectId('5d53b36f607e5e5c7218fa97'),
#   'corpus': 'Do NOT BUY! It says 32 gb but it’s not even  1'},
#  {'_id': ObjectId('5d53b36f607e5e5c7218fa98'), 'corpus': 'Naba Nada'},
#  {'_id': ObjectId('5d53b36f607e5e5c7218fa99'),
#   'corpus': 'Good buy Excellent item 👍'},
#  {'_id': ObjectId('5d53b36f607e5e5c7218fa9a'),
#   'corpus': 'Buy this Would buy again.'},
#  {'_id': ObjectId('5d53b36f607e5e5c7218fa9b'),
#   'corpus': "You can't beat this. great sd card."},
#  {'_id': ObjectId('5d53b36f607e5e5c7218fa9c'),
#   'corpus': 'Good SD card. Use these in my camera, tablet, and security webcam.  Works well in all of them.'},
#  {'_id': ObjectId('5d53b36f607e5e5c7218fa9d'),
#   'corpus': 'Fast, but occasionally disconnects Fast and easy to work with both a phone and the sd adapter. It sometimes randomly disconnects though but very rarely'},
#  {'_id': ObjectId('5d53b372607e5e5c7218fa9e'),
#   'corpus': 'Works great Works great no issues'},
#  {'_id': ObjectId('5d53b372607e5e5c7218fa9f'),
#   'corpus': 'I like it I like it'},
#  {'_id': ObjectId('5d53b372607e5e5c7218faa0'),
#   'corpus': 'Its working. Dash camera'},
#  {'_id': ObjectId('5d53b372607e5e5c7218faa1'),
#   'corpus': 'I will buy more of this great product Real good product for great price. Loved it!'},
#  {'_id': ObjectId('5d53b372607e5e5c7218faa2'),
#   'corpus': 'Good deal great price Great price'},
#  {'_id': ObjectId('5d53b372607e5e5c7218faa3'), 'corpus': 'Good Good product.'},
#  {'_id': ObjectId('5d53b372607e5e5c7218faa4'),
#   'corpus': "It's ok. Could be better I was using this sd card for storage on my wireless security camera. I was getting around 30gb consistently. But as the other day, it is coming up as corrupted and I am un able to format. It just keeps throwing errors no matter what I try."},
#  {'_id': ObjectId('5d53b372607e5e5c7218faa5'),
#   'corpus': 'Only 1 of 3 cards worked I ordered two of these and one did not work in my camera. Amazon sent me a replacement and that one didn’t work either. I know it’s the memory card and not the camera because I have two cameras and I swapped the memory cards and the faulty one didn’t work and either camera but a good one worked in both cameras.  I’m going to try to return it but it’s so inconvenient but only one has worked and I have to get a memory card from somewhere else or risk ordering another one from here and have it also not work.'},
#  {'_id': ObjectId('5d53b372607e5e5c7218faa6'), 'corpus': 'good good'},
#  {'_id': ObjectId('5d53b372607e5e5c7218faa7'),
#   'corpus': 'Works well It’s a good sad card, so far I haven’t had a single problem with it.'},
#  {'_id': ObjectId('5d53b379607e5e5c7218faa8'),
#   'corpus': 'Amazing Amazing it work with my phone and camera'},
#  {'_id': ObjectId('5d53b379607e5e5c7218faa9'),
#   'corpus': "It's okay for the price Using it for my security camera.Wish it was much cheaper though  :/"},
#  {'_id': ObjectId('5d53b379607e5e5c7218faaa'),
#   'corpus': 'Capacity Can’t really review.'},
#  {'_id': ObjectId('5d53b379607e5e5c7218faab'),
#   'corpus': 'Perfect No problems at all'},
#  {'_id': ObjectId('5d53b379607e5e5c7218faac'),
#   'corpus': 'Runs out great Runs out great'},
#  {'_id': ObjectId('5d53b379607e5e5c7218faad'),
#   'corpus': "Waste of money didn't work at all. Card did not register on multiple devices tested. Too much trouble for refund since having to pay out of pocket to mail back. And wait weeks for pocket change."},
#  {'_id': ObjectId('5d53b379607e5e5c7218faae'),
#   'corpus': 'Good buy, works as it should Used for dash cam recording. Works as it should.'},
#  {'_id': ObjectId('5d53b379607e5e5c7218faaf'),
#   'corpus': 'Happy Customer Item as described, and arrived on time.'},
#  {'_id': ObjectId('5d53b379607e5e5c7218fab0'),
#   'corpus': 'Happy customer. Works great on my off brand action camera. Was able to see my media on my laptop with included adapter.'},
#  {'_id': ObjectId('5d53b379607e5e5c7218fab1'),
#   'corpus': 'Great MicroSD memory card. Excellent choice for a 1080p security camera. The write speed is more than sufficient to capture still shots and record video for several weeks.'},
#  {'_id': ObjectId('5d53b37c607e5e5c7218fab2'),
#   'corpus': 'Excelente producto Muy buena calidad'},
#  {'_id': ObjectId('5d53b37c607e5e5c7218fab3'),
#   'corpus': "Fast and reliable The transfer is very fast, it looks good, and it's quite cheap for a good quality 32GB card"},
#  {'_id': ObjectId('5d53b37c607e5e5c7218fab4'),
#   'corpus': 'Good Does what it says it will do.'},
#  {'_id': ObjectId('5d53b37c607e5e5c7218fab5'),
#   'corpus': 'A great and reasonably priced product Great product'},
#  {'_id': ObjectId('5d53b37c607e5e5c7218fab6'),
#   'corpus': 'Muy buena calidad Es bueno'},
#  {'_id': ObjectId('5d53b37c607e5e5c7218fab7'),
#   'corpus': 'Excelente Excelente'},
#  {'_id': ObjectId('5d53b37c607e5e5c7218fab8'),
#   'corpus': 'Simply put “great product “ Great product'},
#  {'_id': ObjectId('5d53b37c607e5e5c7218fab9'),
#   'corpus': "Don't miss out, great product. Just as described."},
#  {'_id': ObjectId('5d53b37c607e5e5c7218faba'),
#   'corpus': 'Excelente producto. Es muy buen producto. Lo recomiendo.'},
#  {'_id': ObjectId('5d53b37c607e5e5c7218fabb'),
#   'corpus': 'Good quality Very good quality and storage amount for the money.'},
#  {'_id': ObjectId('5d53b37f607e5e5c7218fabc'),
#   'corpus': 'Good Deal good product Storage space is decent.  Good item for using with recorder'},
#  {'_id': ObjectId('5d53b37f607e5e5c7218fabd'),
#   'corpus': 'Fast, cheap, and legit Good card, got advertised speeds and storage.  Would purchase again.'},
#  {'_id': ObjectId('5d53b37f607e5e5c7218fabe'), 'corpus': 'Good Grate'},
#  {'_id': ObjectId('5d53b37f607e5e5c7218fabf'),
#   'corpus': 'Product does the job Does the job as expected'},
#  {'_id': ObjectId('5d53b37f607e5e5c7218fac0'),
#   'corpus': 'NO ISSUES DOES WHAT I NEED WELL'},
#  {'_id': ObjectId('5d53b37f607e5e5c7218fac1'),
#   'corpus': "Good for a smartphone Exactly what I needed to take to the Philippines for daughter and wife's phone"},
#  {'_id': ObjectId('5d53b37f607e5e5c7218fac2'),
#   'corpus': 'How do they do it? So mush storage in such a small chip.'},
#  {'_id': ObjectId('5d53b37f607e5e5c7218fac3'),
#   'corpus': 'As expected As expected'},
#  {'_id': ObjectId('5d53b37f607e5e5c7218fac4'),
#   'corpus': 'Great Product I bought these micro rams, for My 2 boys, outdoor cams. Great price and Product.'},
#  {'_id': ObjectId('5d53b37f607e5e5c7218fac5'),
#   'corpus': 'Great Works great for raspberry 3b+'},
#  {'_id': ObjectId('5d53b383607e5e5c7218fac6'),
#   'corpus': 'As advertised As advertised'},
#  {'_id': ObjectId('5d53b383607e5e5c7218fac7'),
#   'corpus': 'A tiny wonder This little card stores and plays back music in an MP3 player and the sound clarity is very good'},
#  {'_id': ObjectId('5d53b383607e5e5c7218fac8'),
#   'corpus': 'Works great, no issue so far Works great! I use it in a indoor camera and so far no issues at all.'},
#  {'_id': ObjectId('5d53b383607e5e5c7218fac9'),
#   'corpus': 'Great Bought for my daughters first birthday.'},
#  {'_id': ObjectId('5d53b383607e5e5c7218faca'),
#   'corpus': 'good quick memory transfer rate are good on this memory'},
#  {'_id': ObjectId('5d53b383607e5e5c7218facb'),
#   'corpus': 'Great 4 storage Holds a lot great 4 pictures'},
#  {'_id': ObjectId('5d53b383607e5e5c7218facc'),
#   'corpus': 'Value for money Nice SD card, i bought it for my retropie setup.'},
#  {'_id': ObjectId('5d53b383607e5e5c7218facd'),
#   'corpus': 'Dependable Very good and good price'},
#  {'_id': ObjectId('5d53b383607e5e5c7218face'),
#   'corpus': 'Does what it needs to do So far so good!'},
#  {'_id': ObjectId('5d53b383607e5e5c7218facf'),
#   'corpus': "Previous memory chip failed this one replaced and working fine The previous memory chip on my daughter's cell phone failed.  It was made by a different company.  She lost some of her stuff which she was unhappy about.  I bought this for her and so far so good.  I do not know if one brand fails more often than other but so far so good with this Samsung memory chip."},
#  {'_id': ObjectId('5d53b388607e5e5c7218fad0'),
#   'corpus': 'Big storage, small price! The card works well and doubles the storage of my moto g7'},
#  {'_id': ObjectId('5d53b388607e5e5c7218fad1'),
#   'corpus': 'Had what I was looking for Good deal'},
#  {'_id': ObjectId('5d53b388607e5e5c7218fad2'),
#   'corpus': 'Great transaction Super great'},
#  {'_id': ObjectId('5d53b388607e5e5c7218fad3'),
#   'corpus': "Doesn't work with yi cameras Great sd card but doesn't work with camera."},
#  {'_id': ObjectId('5d53b388607e5e5c7218fad4'), 'corpus': 'Good Good deal'},
#  {'_id': ObjectId('5d53b388607e5e5c7218fad5'),
#   'corpus': "Corrupted after 1 year in a Samsung Smart Cam Pro Worked fine for awhile then noticed my cameras weren't active anymore and would only work when I removed the SDCards. Put them in my computer SD Slot and they fail to format."},
#  {'_id': ObjectId('5d53b388607e5e5c7218fad6'),
#   'corpus': 'Good product Good product, I like the presentation and the shipping was fast'},
#  {'_id': ObjectId('5d53b388607e5e5c7218fad7'),
#   'corpus': "Easy to set up It is what it is.it stores some apps. That's why I bought 2of them."},
#  {'_id': ObjectId('5d53b388607e5e5c7218fad8'),
#   'corpus': 'Good quality Worked well on my phone'},
#  {'_id': ObjectId('5d53b388607e5e5c7218fad9'),
#   'corpus': 'Excelente EXCELENTE'},
#  {'_id': ObjectId('5d53b38b607e5e5c7218fada'),
#   'corpus': "Buy, there's no reason not to and your equipment will thank you. Easy access and we bought multiple for the cameras. Fast transfer and low cost these are perfect for photos and videos shot raw format too. Highly recommend."},
#  {'_id': ObjectId('5d53b38b607e5e5c7218fadb'),
#   'corpus': 'Memory card As expected'},
#  {'_id': ObjectId('5d53b38b607e5e5c7218fadc'),
#   'corpus': 'Pricey Like to product but paid too much for it. I found other memory cards with more GB for less.'},
#  {'_id': ObjectId('5d53b38b607e5e5c7218fadd'),
#   'corpus': "Less than what I paid for I brought 2 32GB but thats not what I got why are you charging for 32GB? And I'm getting less than what I paid forAt this point im totally annoyed brought these cards and they are both saying not enough storage space. I live in the Caribbean where 1us is 6.25 or more the rate I purchase these cards were $7.14 so I paid $114.89 then add on tax😠 and both of them are not working this is ridiculous."},
#  {'_id': ObjectId('5d53b38b607e5e5c7218fade'),
#   'corpus': 'Great deal I mostly used this to hold photos and not only does it hold a good amount it also was pretty cheap so it’s a good bang for you buck in my opinion'},
#  {'_id': ObjectId('5d53b38b607e5e5c7218fadf'),
#   'corpus': "works very well holds a LOT of pictures can't really say more about it"},
#  {'_id': ObjectId('5d53b38b607e5e5c7218fae0'), 'corpus': 'Nice Good'},
#  {'_id': ObjectId('5d53b38b607e5e5c7218fae1'),
#   'corpus': 'No problems Has no problems works good'},
#  {'_id': ObjectId('5d53b38b607e5e5c7218fae2'),
#   'corpus': 'Thank you Husband loves'},
#  {'_id': ObjectId('5d53b38b607e5e5c7218fae3'),
#   'corpus': 'Meh Unseats too easy and phone stops recognizing it when it works with others'},
#  {'_id': ObjectId('5d53b390607e5e5c7218fae4'),
#   'corpus': 'Muy buen artículo Buen artículo'},
#  {'_id': ObjectId('5d53b390607e5e5c7218fae5'),
#   'corpus': 'Works well Works as it should.'},
#  {'_id': ObjectId('5d53b390607e5e5c7218fae6'),
#   'corpus': 'Good storage micro storage. Great product for the price.'},
#  {'_id': ObjectId('5d53b390607e5e5c7218fae7'),
#   'corpus': 'Just what I needed Sold exactly as was described and worked perfectly.'},
#  {'_id': ObjectId('5d53b390607e5e5c7218fae8'),
#   'corpus': 'Oops... I bought this by mistake! I have no idea... Apparently l bought this and it was the wrong item... My own fault so giving 5 stars!'},
#  {'_id': ObjectId('5d53b390607e5e5c7218fae9'),
#   'corpus': 'Works like its supposed to Liked it just fine'},
#  {'_id': ObjectId('5d53b390607e5e5c7218faea'),
#   'corpus': 'Great device Great device'},
#  {'_id': ObjectId('5d53b390607e5e5c7218faeb'),
#   'corpus': 'Fantastic Great device, fantastic storage capacity, fast response, no problems at all.100% happy.'},
#  {'_id': ObjectId('5d53b390607e5e5c7218faec'),
#   'corpus': 'Waste of money Very slow transfer speed. Corrupted image files. Doesnt like raw files.'},
#  {'_id': ObjectId('5d53b390607e5e5c7218faed'),
#   'corpus': 'Bought quite a few of these to use with cctv or any other small devices around the house Samsung EVO select memory cards have consistently perform for my devices. I have no issues with them at all, and have been using them for as long as I know it.'},
#  {'_id': ObjectId('5d53b396607e5e5c7218faee'),
#   'corpus': 'Fantastic Price was great. Quality was even better! Very impressed'},
#  {'_id': ObjectId('5d53b396607e5e5c7218faef'),
#   'corpus': 'Good price on product. Bought this for drone camera.'},
#  {'_id': ObjectId('5d53b396607e5e5c7218faf0'),
#   'corpus': 'Good SD card Very good micro SD.'},
#  {'_id': ObjectId('5d53b396607e5e5c7218faf1'),
#   'corpus': "works well pretty fast and does what it's supposed to."},
#  {'_id': ObjectId('5d53b396607e5e5c7218faf2'),
#   'corpus': 'Samsung rules... As advertised, max GB for my android TV'},
#  {'_id': ObjectId('5d53b396607e5e5c7218faf3'),
#   'corpus': 'Good card. Does the job. Hasnt had any issues.'},
#  {'_id': ObjectId('5d53b396607e5e5c7218faf4'),
#   'corpus': 'Great micro SD Item as described'},
#  {'_id': ObjectId('5d53b396607e5e5c7218faf5'), 'corpus': 'Works Like'},
#  {'_id': ObjectId('5d53b396607e5e5c7218faf6'),
#   'corpus': 'Great product! Worth the money.'},
#  {'_id': ObjectId('5d53b396607e5e5c7218faf7'),
#   'corpus': 'Excellent quality Very good'},
#  {'_id': ObjectId('5d53b39a607e5e5c7218faf8'),
#   'corpus': 'Dead on arrival Couldn’t be detected by 3 computers and 4 different readers (2 micro SD to SD and 2 micro SD to USB), not even able to reformat.'},
#  {'_id': ObjectId('5d53b39a607e5e5c7218faf9'),
#   'corpus': 'Fast with Quick Access Very fast upload/download speeds.'},
#  {'_id': ObjectId('5d53b39a607e5e5c7218fafa'),
#   'corpus': 'Extra storage with adapter. Worked for what I needed.'},
#  {'_id': ObjectId('5d53b39a607e5e5c7218fafb'),
#   'corpus': 'User friendly is Dummies can fix Good storage and reliable friendly users'},
#  {'_id': ObjectId('5d53b39a607e5e5c7218fafc'),
#   'corpus': 'Love it Fast recovery on info.'},
#  {'_id': ObjectId('5d53b39a607e5e5c7218fafd'),
#   'corpus': 'Plug and play ease Very good plug and play SD card'},
#  {'_id': ObjectId('5d53b39a607e5e5c7218fafe'), 'corpus': '👍 👍'},
#  {'_id': ObjectId('5d53b39a607e5e5c7218faff'),
#   'corpus': 'It a memory card It’s a memory card'},
#  {'_id': ObjectId('5d53b39a607e5e5c7218fb00'),
#   'corpus': 'Just as described Exactly as described and does what I need!'},
#  {'_id': ObjectId('5d53b39a607e5e5c7218fb01'),
# ...
#  {'_id': ObjectId('5d53b490607e5e5c7218fd27'),
#   'corpus': 'work  well work well, read and writer fast'},
#  {'_id': ObjectId('5d53b493607e5e5c7218fd29'),
#   'corpus': 'Excellent Excellent'},
#  {'_id': ObjectId('5d53b493607e5e5c7218fd2a'),
#   'corpus': 'Great price. Great price. Received it right on time.'},
#  {'_id': ObjectId('5d53b493607e5e5c7218fd2b'),
#   'corpus': 'Love the price Great price'},
#  {'_id': ObjectId('5d53b493607e5e5c7218fd2c'),
#   'corpus': "Sd card It's a sd memory card not much to say"},
#  {'_id': ObjectId('5d53b493607e5e5c7218fd2d'),
#   'corpus': 'Good Works as expected.'},
#  {'_id': ObjectId('5d53b493607e5e5c7218fd2e'),
#   'corpus': "It works It works...thats all that is important for me. I can't tell if you its faster or slower than others, but in my outdoor security camera, it works."},
#  {'_id': ObjectId('5d53b493607e5e5c7218fd2f'), 'corpus': 'Love it Love it'},
#  {'_id': ObjectId('5d53b493607e5e5c7218fd30'),
#   'corpus': "Not a good product I brought this for my kindle and phone and it didn't work...terrible product!  DO NOT BUY!"},
#  {'_id': ObjectId('5d53b493607e5e5c7218fd31'),
#   'corpus': 'Doesn’t work Doesn’t even register that it’s a memory card. Pretty sure I bought a piece of plastic.'},
#  {'_id': ObjectId('5d53b49a607e5e5c7218fd32'),
#   'corpus': 'Shipment is fast Does what it should be done'},
#  {'_id': ObjectId('5d53b49a607e5e5c7218fd33'),
#   'corpus': 'Happy with purchase Happy with purchase. Never needed tech support'},
#  {'_id': ObjectId('5d53b49a607e5e5c7218fd34'),
#   'corpus': 'I love this product! I love this product!'},
#  {'_id': ObjectId('5d53b49a607e5e5c7218fd35'),
#   'corpus': 'Great Working great with my dash cam'},
#  {'_id': ObjectId('5d53b49a607e5e5c7218fd36'),
#   'corpus': "Great Micro SD Card I'm very happy with the performance of this memory card, that's why I bought 2 for my cameras."},
#  {'_id': ObjectId('5d53b49a607e5e5c7218fd37'), 'corpus': 'Good Good'},
#  {'_id': ObjectId('5d53b49a607e5e5c7218fd38'),
#   'corpus': 'works great camera recording'},
#  {'_id': ObjectId('5d53b49a607e5e5c7218fd39'),
#   'corpus': 'Use in my car dash cam Haven’t used tech support'},
#  {'_id': ObjectId('5d53b49a607e5e5c7218fd3a'),
#   'corpus': 'Great, low cost for Drone photography. Gotta have, well priced.'},
#  {'_id': ObjectId('5d53b49a607e5e5c7218fd3b'),
#   'corpus': "Fast After trying unoriginal brands i'm pleased with this product"},
#  {'_id': ObjectId('5d53b49c607e5e5c7218fd3d'),
#   'corpus': 'WORKS Does what is suppose to do.Works Great.Thanks,Thelma L.'},
#  {'_id': ObjectId('5d53b49c607e5e5c7218fd3e'),
#   'corpus': 'Great micro sd These seem to be well made micro sd cards. I have purchased several and have not had an issue.'},
#  {'_id': ObjectId('5d53b49c607e5e5c7218fd3f'),
#   'corpus': 'Works great Works great'},
#  {'_id': ObjectId('5d53b49c607e5e5c7218fd40'),
#   'corpus': 'Great Product Works great, just plug and go.'},
#  {'_id': ObjectId('5d53b49c607e5e5c7218fd41'), 'corpus': 'buen producto ok'},
#  {'_id': ObjectId('5d53b49c607e5e5c7218fd42'),
#   'corpus': 'Great product Great product'},
#  {'_id': ObjectId('5d53b49c607e5e5c7218fd43'), 'corpus': 'Excelente Bueno'},
#  {'_id': ObjectId('5d53b49c607e5e5c7218fd44'),
#   'corpus': 'Great! Great for my old smartphones!'},
#  {'_id': ObjectId('5d53b49c607e5e5c7218fd45'),
#   'corpus': 'Perfect for camera Brought for  camera recording'},
#  {'_id': ObjectId('5d53b49f607e5e5c7218fd46'),
#   'corpus': 'five stars! excellent product. the worst thing is that it raised $ 2. a shame.'},
#  {'_id': ObjectId('5d53b49f607e5e5c7218fd47'),
#   'corpus': 'Worth the price at the time of purchase. Worth the price at the time of purchase.'},
#  {'_id': ObjectId('5d53b49f607e5e5c7218fd48'),
#   'corpus': 'Samsung products are great Works great!'},
#  {'_id': ObjectId('5d53b49f607e5e5c7218fd49'),
#   'corpus': 'Not a bad buy Great storage for price'},
#  {'_id': ObjectId('5d53b49f607e5e5c7218fd4a'),
#   'corpus': 'So far so good I am using them on security cameras.  Most memory cards from reputable companies these days  are pretty good'},
#  {'_id': ObjectId('5d53b49f607e5e5c7218fd4b'), 'corpus': 'Great Great'},
#  {'_id': ObjectId('5d53b49f607e5e5c7218fd4c'),
#   'corpus': 'What a great memory card! High quality card.'},
#  {'_id': ObjectId('5d53b49f607e5e5c7218fd4d'), 'corpus': 'Good product 👍🙂'},
#  {'_id': ObjectId('5d53b49f607e5e5c7218fd4e'),
#   'corpus': 'Good Deal. works great. Good Deal. works great.'},
#  {'_id': ObjectId('5d53b49f607e5e5c7218fd4f'),
#   'corpus': 'GREAT PRODUCT  QUICK DELIVERY EXCELLENT/ AS  ADVERTISED'},
#  {'_id': ObjectId('5d53b4a5607e5e5c7218fd50'),
#   'corpus': 'FAST What else matters? This thing is F-A-S-T. I am using it in my ROAV car dash cam.'},
#  {'_id': ObjectId('5d53b4a5607e5e5c7218fd51'),
#   'corpus': 'Stopped working in less than three months I bought this in January 2019.As of March 10, 2019, the card is not readable.'},
#  {'_id': ObjectId('5d53b4a5607e5e5c7218fd52'), 'corpus': 'as described Good'},
#  {'_id': ObjectId('5d53b4a5607e5e5c7218fd53'),
#   'corpus': 'Fit perfectly! Product as described highly recommend! Fit perfectly! Product as described highly recommend!'},
#  {'_id': ObjectId('5d53b4a5607e5e5c7218fd54'),
#   'corpus': "Great for Raspberry Pi! I've been running this for about a month in my Raspberry Pi and had no issues whatsoever. OS speed seems great with Raspbian. It's an SD card, it does exactly what it's supposed to do!"},
#  {'_id': ObjectId('5d53b4a5607e5e5c7218fd55'),
#   'corpus': 'Great purchase! Works for the security camera I bought. Perfect. Not too much not too little. Perfect for my use.'},
#  {'_id': ObjectId('5d53b4a5607e5e5c7218fd56'), 'corpus': 'Nice Nice'},
#  {'_id': ObjectId('5d53b4a5607e5e5c7218fd57'), 'corpus': 'excelente bueno'},
#  {'_id': ObjectId('5d53b4a5607e5e5c7218fd58'),
#   'corpus': 'Basic sd card Good sd cards no issues so far.'},
#  {'_id': ObjectId('5d53b4a5607e5e5c7218fd59'),
#   'corpus': 'Works as advertised. Using for a dash cam. Comes with an SD adaptor.'},
#  {'_id': ObjectId('5d53b4a9607e5e5c7218fd5a'),
#   'corpus': 'Convinient fits my kids fire tablet.'},
#  {'_id': ObjectId('5d53b4a9607e5e5c7218fd5b'),
#   'corpus': 'Great product Bought this for my phone and so far so good, I am able to load a lot of songs and videos and they all play good'},
#  {'_id': ObjectId('5d53b4a9607e5e5c7218fd5c'),
#   'corpus': 'Item was as described Item was as described'},
#  {'_id': ObjectId('5d53b4a9607e5e5c7218fd5d'),
#   'corpus': 'Great product at a great price! I’m very pleased!  Thank you!'},
#  {'_id': ObjectId('5d53b4a9607e5e5c7218fd5e'),
#   'corpus': 'Samsung, excellent microSDHC card! Handy 32GB SDHC card for Raspberry Pi'},
#  {'_id': ObjectId('5d53b4a9607e5e5c7218fd5f'),
#   'corpus': 'Buen producto Buen producto'},
#  {'_id': ObjectId('5d53b4a9607e5e5c7218fd60'),
#   'corpus': 'Good buy Its a memory card.. works quickly with apps and videos'},
#  {'_id': ObjectId('5d53b4a9607e5e5c7218fd61'),
#   'corpus': 'Oferta real, recomendada... Tal como lo esperado ...'},
#  {'_id': ObjectId('5d53b4a9607e5e5c7218fd62'),
#   'corpus': 'Just as described Came really quick and is just as described!'},
#  {'_id': ObjectId('5d53b4a9607e5e5c7218fd63'),
#   'corpus': 'Always good Samsung just works.'},
#  {'_id': ObjectId('5d53b4ad607e5e5c7218fd64'),
#   'corpus': 'Dead out of the box - burnt hot I formatted the SD card,  and it did not work at first run.  Card got extremely hot.  My other SD card works just fine, in the same card reader.  Amazon refunded very quickly. I sent the card back for said refund.'},
#  {'_id': ObjectId('5d53b4ad607e5e5c7218fd65'),
#   'corpus': 'Works great with my dash cam ce50 Ran a speed test and it works perfectly great  Quality I use it at 4K 30 frames'},
#  {'_id': ObjectId('5d53b4ad607e5e5c7218fd66'),
#   'corpus': "A+ product Perfect memory card for a cell phone.  Not only does it hold photos but it also holds apps making it that much more useful and you can't beat the price"},
#  {'_id': ObjectId('5d53b4ad607e5e5c7218fd67'),
#   'corpus': 'excellent,fast delivery i like this product'},
#  {'_id': ObjectId('5d53b4ad607e5e5c7218fd68'),
#   'corpus': 'good stuff good stuff'},
#  {'_id': ObjectId('5d53b4ad607e5e5c7218fd69'),
#   'corpus': 'Highly recommended Love the versatility with it having the different sizes, the speed is great to'},
#  {'_id': ObjectId('5d53b4ad607e5e5c7218fd6a'),
#   'corpus': 'New Life, New Games, More of everything Gave my phone much needed space, can play all the games i wanna play and have tons more music to listen to on long trips and walks.  Nice speeds as well.  Recommend to everyone.'},
#  {'_id': ObjectId('5d53b4ad607e5e5c7218fd6b'),
#   'corpus': "It works. It's an SD card, functions as an SD card should......."},
#  {'_id': ObjectId('5d53b4ad607e5e5c7218fd6c'),
#   'corpus': 'Good find Good find'},
#  {'_id': ObjectId('5d53b4ad607e5e5c7218fd6d'),
#   'corpus': 'Nice product Just as expected'},
#  {'_id': ObjectId('5d53b4b0607e5e5c7218fd6e'), 'corpus': 'good buen producto'},
#  {'_id': ObjectId('5d53b4b0607e5e5c7218fd6f'),
#   'corpus': 'very good tf card  for the money the card works faster than most tf cards that is a plus  to me thank you for sending it out to me'},
#  {'_id': ObjectId('5d53b4b0607e5e5c7218fd70'),
#   'corpus': 'Its real It holds a lot of music'},
#  {'_id': ObjectId('5d53b4b0607e5e5c7218fd71'),
#   'corpus': 'Works as advertised. It works great with my samsung phone. I do not have any issues with it.'},
#  {'_id': ObjectId('5d53b4b0607e5e5c7218fd72'),
#   'corpus': 'Perfect Exactly what we needed to go with our new Yi Home camera.'},
#  {'_id': ObjectId('5d53b4b0607e5e5c7218fd73'),
#   'corpus': "I'm very happy with this item and I'll recommend it to my friends. A+ I'm very happy with this item and I'll recommend it to my friends. A+"},
#  {'_id': ObjectId('5d53b4b0607e5e5c7218fd74'),
#   'corpus': 'Worthless WIthin 3 days it stopped being read by my brand new dash cam. Will be switching to another brand.'},
#  {'_id': ObjectId('5d53b4b0607e5e5c7218fd75'),
#   'corpus': 'Great Price/Deal Excellent product.'},
#  {'_id': ObjectId('5d53b4b0607e5e5c7218fd76'),
#   'corpus': 'returned did not fit phone'},
#  {'_id': ObjectId('5d53b4b0607e5e5c7218fd77'),
#   'corpus': 'Works great Works with LG harmony'},
#  {'_id': ObjectId('5d53b4b3607e5e5c7218fd78'),
#   'corpus': "Tablet that suits my needs I needed more GOD'S in my tablet."},
#  {'_id': ObjectId('5d53b4b3607e5e5c7218fd79'),
#   'corpus': 'Perfect Perfect for what I needed at a great price! Came on time, no delays, no damaged package.'},
#  {'_id': ObjectId('5d53b4b3607e5e5c7218fd7a'),
#   'corpus': 'A very good product. They work well.'},
#  {'_id': ObjectId('5d53b4b3607e5e5c7218fd7b'),
#   'corpus': 'Mini sd card Easy to install and preforms Great.'},
#  {'_id': ObjectId('5d53b4b3607e5e5c7218fd7c'),
#   'corpus': 'Perfect Just what I needed.'},
#  {'_id': ObjectId('5d53b4b3607e5e5c7218fd7d'), 'corpus': 'memory great'},
#  {'_id': ObjectId('5d53b4b3607e5e5c7218fd7e'),
#   'corpus': 'Great Product Awesome price.'},
#  {'_id': ObjectId('5d53b4b3607e5e5c7218fd7f'),
#   'corpus': "Works great! Samsung never lets me down. This is a great memory card and I'll definitely purchase more as I need them."},
#  {'_id': ObjectId('5d53b4b3607e5e5c7218fd80'),
#   'corpus': 'A+ Excellent item and delivery service'},
#  {'_id': ObjectId('5d53b4b3607e5e5c7218fd81'),
#   'corpus': 'Good quality for a good price A solid card. I’ve been using it for my dash cam.'},
#  {'_id': ObjectId('5d53b4b9607e5e5c7218fd82'),
#   'corpus': 'Perfect for my Android Box I bought this to add memory to an Android box I purchased the same day. The box formatted it easily and now I have 48GB of memory at my disposal. Great investment at a great price.'},
#  {'_id': ObjectId('5d53b4b9607e5e5c7218fd83'),
#   'corpus': 'Super fast card These are great SD cards they are super fast especially with a Samsung phone nothing bad to say'},
#  {'_id': ObjectId('5d53b4b9607e5e5c7218fd84'),
#   'corpus': 'I always buy this brand of SD cards, they always work I always buy Samsung memory cards cause they plain work all the time without any failures, IMO, your mileage may vary on these, mine is a perfect track record and I bet I have bought over 20 cards in the past 5 years.'},
#  {'_id': ObjectId('5d53b4b9607e5e5c7218fd85'),
#   'corpus': 'JUST WHAT I ORDERED IT WORKS. NO COMPLAINTS'},
#  {'_id': ObjectId('5d53b4b9607e5e5c7218fd86'), 'corpus': 'Nice It work well'},
#  {'_id': ObjectId('5d53b4b9607e5e5c7218fd87'),
#   'corpus': 'yes Shipped fast,  and great price'},
#  {'_id': ObjectId('5d53b4b9607e5e5c7218fd88'),
#   'corpus': "Works as described 4 stars because it's been a little glitchy. I've had to reformat once already because it corrupted. I only use it for my 3D printer files."},
#  {'_id': ObjectId('5d53b4b9607e5e5c7218fd89'),
#   'corpus': 'Great speed for the price! Very fast card. I just installed it into my phone.  And I definitely notice my phone runs faster after moving all my apps over to the card.  Definitely recommend this high speed sd card!'},
#  {'_id': ObjectId('5d53b4b9607e5e5c7218fd8a'),
#   'corpus': 'Serves its purpose Serves its purpose'},
#  {'_id': ObjectId('5d53b4b9607e5e5c7218fd8b'),
#   'corpus': 'Great valie Works well, no issues formatting the memory or using it in my digital camera. The adapter allows you to insert the card in a standard SD reader.'},
#  {'_id': ObjectId('5d53b4bd607e5e5c7218fd8c'),
#   'corpus': 'Llegó en buenas condiciones Todo bien'},
#  {'_id': ObjectId('5d53b4bd607e5e5c7218fd8d'), 'corpus': '👍 👍'},
#  {'_id': ObjectId('5d53b4bd607e5e5c7218fd8e'),
#   'corpus': 'Fast class 10 As described'},
#  {'_id': ObjectId('5d53b4bd607e5e5c7218fd8f'),
#   'corpus': "Multiple Devices It's just great works for different purposesPhone,body camera,tablet ect."},
#  {'_id': ObjectId('5d53b4bd607e5e5c7218fd90'),
#   'corpus': 'Very good quality Item Like it is fast and small and works well with any devices.'},
#  {'_id': ObjectId('5d53b4bd607e5e5c7218fd91'),
#   'corpus': 'It did not work when I got it I got two of these and one did not work when I got it the other did'},
#  {'_id': ObjectId('5d53b4bd607e5e5c7218fd92'),
#   'corpus': 'Very good memory card Will work in my drone when I get it.'},
#  {'_id': ObjectId('5d53b4bd607e5e5c7218fd93'),
#   'corpus': 'When you need it ▀▄▀▄▀▄▀▄▀▄█QUIK▓ PERFECT★★★★★5 STARS GR8T item IMPRESSIVE SELLER Thanks!'},
#  {'_id': ObjectId('5d53b4bd607e5e5c7218fd94'),
#   'corpus': 'SD card for Security camera Not sure if this is a good product. I have had two cards go out on my security cameras. Trying to contact Samsung for product warranty support and I get no where?'},
#  {'_id': ObjectId('5d53b4bd607e5e5c7218fd95'),
#   'corpus': "Works great What else is there to say. It's Samsung"},
#  {'_id': ObjectId('5d53b4c4607e5e5c7218fd96'),
#   'corpus': 'Great material It works'},
#  {'_id': ObjectId('5d53b4c4607e5e5c7218fd97'),
#   'corpus': 'Good product! I have used this product. I like it very much. It meets my need.'},
#  {'_id': ObjectId('5d53b4c4607e5e5c7218fd98'), 'corpus': 'Nice Works'},
#  {'_id': ObjectId('5d53b4c4607e5e5c7218fd99'), 'corpus': 'Great Works great'},
#  {'_id': ObjectId('5d53b4c4607e5e5c7218fd9a'),
#   'corpus': "Never had an issue. While I can't speak to technical specs of this card. As I've never tried to test it, has always been fine for me. I'm a bit of a Samsung guy so I trust most of their products. Have stuck an evo in all my phones, cameras, and tablet. Never had an issue with any of them and would recommend them to anyone."},
#  {'_id': ObjectId('5d53b4c4607e5e5c7218fd9b'),
#   'corpus': 'Good value Excellent product. Will buy again.'},
#  {'_id': ObjectId('5d53b4c4607e5e5c7218fd9c'),
#   'corpus': 'Happy Customer Well, it works as it’s supposed to.'},
#  {'_id': ObjectId('5d53b4c4607e5e5c7218fd9d'),
#   'corpus': 'Delivery and quality Very nice product.'},
#  {'_id': ObjectId('5d53b4c4607e5e5c7218fd9e'), 'corpus': 'Good Nice'},
#  {'_id': ObjectId('5d53b4c4607e5e5c7218fd9f'),
#   'corpus': 'Muy buena calidad Llego a tiempo'},
#  {'_id': ObjectId('5d53b4c7607e5e5c7218fda0'),
#   'corpus': 'Good product Good product'},
#  {'_id': ObjectId('5d53b4c7607e5e5c7218fda1'),
#   'corpus': 'Good product. Worked.'},
#  ...]

# %%
df = pd.DataFrame(col)
df.head(3)
# Out:
#                         _id                                             corpus
# 0  5d53b24de7f56061ea1f9581                                          Good Good
# 1  5d53b24de7f56061ea1f9582  Needed this memory card for my Action Camera. ...
# 2  5d53b24de7f56061ea1f9583          I just got it today works good Works good

# %%
corpus = [i['corpus'] for i in col]
corpus[0:10]
# Out:
# ['Good Good',
#  'Needed this memory card for my Action Camera. Works great in my Full HD Action Camera. I highly recommend this memory card. :))',
#  'I just got it today works good Works good',
#  'Samsung it’s really good quality Bought it for a friend and really liked it',
#  'No Lamentablemente pedí que enviaran todos los artículos en un solo paquete y no fue así.',
#  '👍🏽 👍🏽',
#  'GOOD LIKE IT',
#  'Thank you very good Thank you very good',
#  'Very good product It is used to keep data out from my phone',
#  'bon merci']

# %%
df.info()
len(corpus)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35667 entries, 0 to 35666
# Data columns (total 2 columns):
# _id       35667 non-null object
# corpus    35667 non-null object
# dtypes: object(2)
# memory usage: 557.4+ KB
# 35667

# %%
from ratelimiter import RateLimiter

# %%
import pickle

# %%
import copy

# %%
col = copy.deepcopy(corpus)

# %%
import sys

# %%
# Dividing Task
n = 25

final = [col[i * n:(i + 1) * n] for i in range((len(col) + n - 1) // n )]

# %%
db.project.temp.insert({'batch_num': 999, 'batch_obj': final[0]})
# Out:
# /Users/panherbert/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
# ObjectId('5d5e173dee5dc46c829612de')

# %%
list(db.project.temp.find())
# Out:
# []

# %%
db.project.temp.delete_one({'batch_num': 999})
list(db.project.temp.find())
# Out:
# []

# %%
response = lambda x: client.batch_detect_sentiment(
    TextList=x,
    LanguageCode='en'
)

# %%
df.head()
# Out:
#                         _id                                             corpus
# 0  5d53b24de7f56061ea1f9581                                          Good Good
# 1  5d53b24de7f56061ea1f9582  Needed this memory card for my Action Camera. ...
# 2  5d53b24de7f56061ea1f9583          I just got it today works good Works good
# 3  5d53b24de7f56061ea1f9584  Samsung it’s really good quality Bought it for...
# 4  5d53b24de7f56061ea1f9585  No Lamentablemente pedí que enviaran todos los...

# %%
rate_limiter = RateLimiter(max_calls=20, period=1)

# %%
# Out:
# ['It\'s a winner! The genuine Samsung Evo Select line of Micro SD cards are great. They are reliable and they live up to the speed and capacity classifications they claim to. I\'ve been using Samsung cards for years and they are the only brand that consistently doesn\'t give me any issues year after year.This 32GB card is no exception. However, by default the card is formatted as FAT32, but I prefer exFAT as FAT32 won\'t allow you to transfer a folder containing more than 4GB to the card. That\'s annoying if you are moving data from an old card to a new one. FAT32 has 4GB file size limitations, but on a transfer it recognizes a directory containing lots of files as 1 thing, and applies the 4GB limit. This will give you an error (in Windows anyway) that there isn\'t enough space available for the transfer. But if you copy the files individually it works fine. Or just format the card to exFAT and it will accept the folder that exceeds 4GB easily. exFAT will work just fine in an Android phone as well (Android 5.1 or higher. Earlier versions may have some issues with the exFAT formatting)This card handles full HD Video at 60FPS without faulting. It\'s write speeds are fine to use for HD video.But be sure to authenticate the card upon arrival to make sure it\'s a genuine Samsung card with the stated capacity. Micro SD cards are a favorite thing for fraudsters to counterfeit because it\'s cheap and easy to do it. In the past the regular Evo line of Samsung cards (the white and orange colored ones) where the popular cards to counterfeit. Though with these higher grade cards (Evo Select line with the white and green color scheme) starting to be more popular......well it behooves anyone buying a new SD card to check it\'s authenticity upon arrival. The 2 tone fade of the green coloring adds an additional anti-counterfeiting measure over the previous solid colors. This makes it more expensive to counterfeit a Samsung card convincingly.What happens is that fraudulent card makers will take a 4GB Class 1 card that costs $1 to make, and hack the control chip that tells the computer what the capacity of the card is so your computer thinks it\'s a much larger card. Your computer will even try to write well over 4GB of data, but the data doesn\'t actually go anywhere. It\'s the same idea as putting a 100 gallon label on a 10 gallon bucket. You can pour 100 gallons into it, but 90 of those gallons are just going to flow out over the top and be lost forever.Below are some steps to help you ensure that you get a legitimate Samsung card.❖ For the last several years Samsung has made it\'s micro SD cards with white plastic. That means the actual card itself behind the colorful label on front is white. You can see the white plastic on the sides. Fake cards are almost always all black, because they are generically produced low cost cards that are given a fancy Samsung looking label on the front. If the card you get it black ON THE SIDES, it\'s not a Samsung. White plastic is more expensive to make, and fraudsters are all about doing it cheap. (See my images below of a real Samsung card with the white sides and back showing) The back should be black. The sides should be white. And the front should be colorful with the 2 tone green fade.❖ Buy only from reputable vendors. Amazon is a reliable vendor. And if there is a problem, they will take it back without hassle. There are dozens of other 3rd party vendors who are just as trustworthy. But make sure you are buying from one of those. Read their seller feedback. If there are numerous complaints from people who bought fake capacity cards or even cards that didn\'t work properly, find a different seller.❖ Make sure the listing looks right. This one is fine. It\'s a legitimate Samsung card. (I\'ve personally bought it and tested it) But scammers will post nearly identical looking listings on Amazon that have cards that look nearly identical buy don\'t have the Samsung logo at the top. (Recently another scamm ...
